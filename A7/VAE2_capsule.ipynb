# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader
import torchvision.utils as vutils
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
import random
from IPython import get_ipython

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % (2**32 - 1)
    np.random.seed(worker_seed)

def pre_run_cell(_):
    set_seed(12)

ip = get_ipython()
ip.events.register('pre_run_cell', pre_run_cell)

# %% [markdown]
# ## Dataset Introduction
# This dataset contains two sets.
#
# The first set is all goods, the second set contains goods and defective products.
#
# You need to classify the products into defective ones or not, and calculate the accuracy.
#
# The benchmark is accuracy.

# %%
BATCH_SIZE = 64
DATASET = 'capsule'
LR = 5e-4
EPOCHS = 500
TMAX = 100
PTH_PATH = f'./data/pth/vae2_{DATASET}.pth'
LATENT_DIM = 128
IMAGE_SIZE = 256

# %%
import glob

transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

class CustomDataset(Dataset):
    def __init__(self, root, transform=None):
        self.root_dir = root
        self.transform = transform
        self.image_paths = glob.glob(f"{root}/*.png")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        img = Image.open(img_path).convert('RGB')
        if self.transform:
            img = self.transform(img)
        label = 0
        return img, label

train_dataset = CustomDataset(root=f'./data/train/{DATASET}', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=11)
val_dataset = CustomDataset(root=f'./data/val/{DATASET}', transform=transform)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=11)


print("train: ", len(train_dataset))
print("val: ", len(val_dataset))
# Out:
# train:  175
# val:  44

# %%
if torch.cuda.is_available():
    device = 'cuda:0'
    print("[INFO] Current device:", torch.cuda.get_device_name(torch.cuda.current_device()), f", device num:{torch.cuda.current_device()}")
elif torch.has_mps:
    device = 'mps'
    print("[INFO] Current device: MAC OS Metal Performance Shaders.")
else:
    device = 'cpu'
    print("[INFO] Current device: CPU")
    print("*"*50,"\n[WARNING] You may need to change the device to GPU or MPS to get better performance.")
    print("*"*50)
device = torch.device(device)
# Out:
# [INFO] Current device: NVIDIA GeForce RTX 4090 , device num:0

# %%
real_batch = next(iter(train_loader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)), cmap='gray')

# %%
import torch
import torch.nn as nn
from torchvision import models

class VAE(nn.Module):
    def __init__(self, latent_dim=128):
        super(VAE, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Flatten(),
            nn.Linear(512 * (IMAGE_SIZE // 32) * (IMAGE_SIZE // 32), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, latent_dim * 2)  # mu and logvar
        )
        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 512 * (IMAGE_SIZE // 32) * (IMAGE_SIZE // 32)),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Unflatten(1, (512, IMAGE_SIZE // 32, IMAGE_SIZE // 32)),
            nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),
            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2, inplace=True),
            nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1),
            nn.Tanh()  # Output range [-1, 1]
        )

        self.apply(self.initialize_weights)

    def initialize_weights(self, m):
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
            nn.init.kaiming_normal_(m.weight, nonlinearity='leaky_relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.Linear):
            nn.init.xavier_normal_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        h = self.encoder(x)
        mu, logvar = torch.chunk(h, 2, dim=-1)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decoder(z)
        return recon_x, mu, logvar

# %%
def loss_function(recon_x, x, mu, logvar):
    recon_loss = nn.functional.mse_loss(recon_x, x, reduction='sum')
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return recon_loss + kl_divergence

# %%
train_losses = []
val_losses = []

def train_vae(model, train_loader, val_loader, optimizer, scheduler, epochs=10):
    global train_losses, val_losses
    train_losses.clear()
    val_losses.clear()
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for batch_idx, (data, _) in enumerate(train_loader):
            data = data.to(device)
            optimizer.zero_grad()
            recon_x, mu, logvar = model(data)
            loss = loss_function(recon_x, data, mu, logvar)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)

        # Validation Phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for data, _ in val_loader:
                data = data.to(device)
                recon_x, mu, logvar = model(data)
                val_loss += loss_function(recon_x, data, mu, logvar).item()
        val_loss /= len(val_loader.dataset)
        val_losses.append(val_loss)
        scheduler.step()

        print(f"Epoch {epoch+1}/{epochs}.. Train Loss: {train_loss:.4f}.. Val Loss: {val_loss:.4f}")

# %%
model = VAE(LATENT_DIM).to(device)
optimizer = optim.AdamW(model.parameters(), lr=LR)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=TMAX, eta_min=1e-6)
total_params = sum(p.numel() for p in model.parameters())
# print(f"Total number of parameters: {total_params}")
train_vae(model, train_loader, val_loader, optimizer, scheduler=scheduler, epochs=EPOCHS)

torch.save(model.state_dict(), PTH_PATH)
# Out:
# Epoch 1/500.. Train Loss: 15233351139.2057.. Val Loss: 109644.8864
# Epoch 2/500.. Train Loss: 19083183.5429.. Val Loss: 423797.9545
# Epoch 3/500.. Train Loss: 4216823.5086.. Val Loss: 108469.8182
# Epoch 4/500.. Train Loss: 107033.8386.. Val Loss: 58289.5341
# Epoch 5/500.. Train Loss: 36568.6393.. Val Loss: 56526.3352
# Epoch 6/500.. Train Loss: 28746.0079.. Val Loss: 58316.7500
# Epoch 7/500.. Train Loss: 23965.3550.. Val Loss: 59973.8864
# Epoch 8/500.. Train Loss: 20847.4418.. Val Loss: 61400.2898
# Epoch 9/500.. Train Loss: 18620.6175.. Val Loss: 62438.0227
# Epoch 10/500.. Train Loss: 16197.4000.. Val Loss: 63034.3352
# Epoch 11/500.. Train Loss: 13864.8607.. Val Loss: 63737.8636
# Epoch 12/500.. Train Loss: 12196.2354.. Val Loss: 64295.4148
# Epoch 13/500.. Train Loss: 10901.5811.. Val Loss: 65183.0341
# Epoch 14/500.. Train Loss: 9789.8964.. Val Loss: 65662.6705
# Epoch 15/500.. Train Loss: 8974.9071.. Val Loss: 65980.2557
# Epoch 16/500.. Train Loss: 8039.1018.. Val Loss: 66042.5170
# Epoch 17/500.. Train Loss: 7217.8580.. Val Loss: 66085.7102
# Epoch 18/500.. Train Loss: 6636.6834.. Val Loss: 66053.6080
# Epoch 19/500.. Train Loss: 6048.4859.. Val Loss: 65908.7045
# Epoch 20/500.. Train Loss: 5604.1165.. Val Loss: 65415.1818
# Epoch 21/500.. Train Loss: 5138.1410.. Val Loss: 64646.0511
# Epoch 22/500.. Train Loss: 4685.2196.. Val Loss: 63791.6023
# Epoch 23/500.. Train Loss: 4377.5175.. Val Loss: 63010.7159
# Epoch 24/500.. Train Loss: 4187.7286.. Val Loss: 62218.8977
# Epoch 25/500.. Train Loss: 3997.4793.. Val Loss: 60648.3125
# Epoch 26/500.. Train Loss: 3840.8671.. Val Loss: 58944.7727
# Epoch 27/500.. Train Loss: 3684.0087.. Val Loss: 57272.9602
# Epoch 28/500.. Train Loss: 3543.0167.. Val Loss: 56335.3977
# Epoch 29/500.. Train Loss: 3417.8118.. Val Loss: 55393.9318
# Epoch 30/500.. Train Loss: 3336.1195.. Val Loss: 47984.4943
# Epoch 31/500.. Train Loss: 3246.6688.. Val Loss: 39848.1364
# Epoch 32/500.. Train Loss: 3153.5049.. Val Loss: 37226.4602
# Epoch 33/500.. Train Loss: 3062.7609.. Val Loss: 37707.8949
# Epoch 34/500.. Train Loss: 2970.1215.. Val Loss: 34525.8352
# Epoch 35/500.. Train Loss: 2907.9243.. Val Loss: 29183.5341
# Epoch 36/500.. Train Loss: 2853.5087.. Val Loss: 25646.5483
# Epoch 37/500.. Train Loss: 2787.8787.. Val Loss: 25651.2983
# Epoch 38/500.. Train Loss: 2720.9908.. Val Loss: 23928.5284
# Epoch 39/500.. Train Loss: 2713.3810.. Val Loss: 15487.3551
# Epoch 40/500.. Train Loss: 2689.9030.. Val Loss: 9717.7926
# Epoch 41/500.. Train Loss: 2618.7749.. Val Loss: 9580.2102
# Epoch 42/500.. Train Loss: 2558.4660.. Val Loss: 10442.0575
# Epoch 43/500.. Train Loss: 2524.5621.. Val Loss: 7791.1612
# Epoch 44/500.. Train Loss: 2477.8990.. Val Loss: 6294.1513
# Epoch 45/500.. Train Loss: 2453.8654.. Val Loss: 5136.3480
# Epoch 46/500.. Train Loss: 2418.9717.. Val Loss: 4579.1619
# Epoch 47/500.. Train Loss: 2373.4058.. Val Loss: 5268.3249
# Epoch 48/500.. Train Loss: 2349.5434.. Val Loss: 3944.6289
# Epoch 49/500.. Train Loss: 2323.1715.. Val Loss: 2741.8272
# Epoch 50/500.. Train Loss: 2298.5163.. Val Loss: 2355.6417
# Epoch 51/500.. Train Loss: 2285.1309.. Val Loss: 2492.7381
# Epoch 52/500.. Train Loss: 2261.7503.. Val Loss: 2468.5241
# Epoch 53/500.. Train Loss: 2227.6284.. Val Loss: 2353.2021
# Epoch 54/500.. Train Loss: 2198.7011.. Val Loss: 2535.8409
# Epoch 55/500.. Train Loss: 2180.2437.. Val Loss: 2370.2456
# Epoch 56/500.. Train Loss: 2158.8359.. Val Loss: 2200.4414
# Epoch 57/500.. Train Loss: 2143.0845.. Val Loss: 2211.1364
# Epoch 58/500.. Train Loss: 2131.8011.. Val Loss: 2245.7718
# Epoch 59/500.. Train Loss: 2117.5800.. Val Loss: 2244.6557
# Epoch 60/500.. Train Loss: 2091.7929.. Val Loss: 2149.7942
# Epoch 61/500.. Train Loss: 2086.7671.. Val Loss: 2127.3176
# Epoch 62/500.. Train Loss: 2087.7948.. Val Loss: 2126.8150
# Epoch 63/500.. Train Loss: 2058.6903.. Val Loss: 2232.3890
# Epoch 64/500.. Train Loss: 2044.4229.. Val Loss: 2148.0655
# Epoch 65/500.. Train Loss: 2040.1979.. Val Loss: 2039.0492
# Epoch 66/500.. Train Loss: 2031.3727.. Val Loss: 2029.7468
# Epoch 67/500.. Train Loss: 2025.2400.. Val Loss: 2083.9100
# Epoch 68/500.. Train Loss: 2006.2707.. Val Loss: 2123.8350
# Epoch 69/500.. Train Loss: 2002.5308.. Val Loss: 2026.0435
# Epoch 70/500.. Train Loss: 1985.3825.. Val Loss: 1992.4002
# Epoch 71/500.. Train Loss: 1985.1937.. Val Loss: 1983.4162
# Epoch 72/500.. Train Loss: 1977.5061.. Val Loss: 1981.2956
# Epoch 73/500.. Train Loss: 1967.8477.. Val Loss: 1986.1797
# Epoch 74/500.. Train Loss: 1962.9683.. Val Loss: 2015.1230
# Epoch 75/500.. Train Loss: 1958.5312.. Val Loss: 1979.7003
# Epoch 76/500.. Train Loss: 1955.8914.. Val Loss: 1943.6436
# Epoch 77/500.. Train Loss: 1949.1080.. Val Loss: 1941.9039
# Epoch 78/500.. Train Loss: 1940.2141.. Val Loss: 1945.7351
# Epoch 79/500.. Train Loss: 1939.9350.. Val Loss: 1928.6928
# Epoch 80/500.. Train Loss: 1940.7196.. Val Loss: 1933.9473
# Epoch 81/500.. Train Loss: 1924.0134.. Val Loss: 1917.8734
# Epoch 82/500.. Train Loss: 1929.8221.. Val Loss: 1920.2308
# Epoch 83/500.. Train Loss: 1924.1600.. Val Loss: 1932.1032
# Epoch 84/500.. Train Loss: 1922.4996.. Val Loss: 1927.0252
# Epoch 85/500.. Train Loss: 1915.5599.. Val Loss: 1924.0437
# Epoch 86/500.. Train Loss: 1920.2359.. Val Loss: 1904.8208
# Epoch 87/500.. Train Loss: 1913.4290.. Val Loss: 1900.8061
# Epoch 88/500.. Train Loss: 1911.4559.. Val Loss: 1904.7219
# Epoch 89/500.. Train Loss: 1913.8617.. Val Loss: 1907.2663
# Epoch 90/500.. Train Loss: 1912.1474.. Val Loss: 1897.9054
# Epoch 91/500.. Train Loss: 1910.3369.. Val Loss: 1901.2702
# Epoch 92/500.. Train Loss: 1910.2978.. Val Loss: 1906.4862
# Epoch 93/500.. Train Loss: 1905.4080.. Val Loss: 1912.1937
# Epoch 94/500.. Train Loss: 1911.9609.. Val Loss: 1893.7317
# Epoch 95/500.. Train Loss: 1904.8359.. Val Loss: 1894.4764
# Epoch 96/500.. Train Loss: 1907.0250.. Val Loss: 1903.9013
# Epoch 97/500.. Train Loss: 1901.4400.. Val Loss: 1904.9922
# Epoch 98/500.. Train Loss: 1906.6495.. Val Loss: 1889.0407
# Epoch 99/500.. Train Loss: 1908.7476.. Val Loss: 1902.4306
# Epoch 100/500.. Train Loss: 1917.3508.. Val Loss: 1899.3155
# Epoch 101/500.. Train Loss: 1909.4724.. Val Loss: 1892.4348
# Epoch 102/500.. Train Loss: 1903.2721.. Val Loss: 1897.2969
# Epoch 103/500.. Train Loss: 1900.9325.. Val Loss: 1880.6818
# Epoch 104/500.. Train Loss: 1906.4067.. Val Loss: 1896.3452
# Epoch 105/500.. Train Loss: 1901.8207.. Val Loss: 1890.9217
# Epoch 106/500.. Train Loss: 1900.0864.. Val Loss: 1905.7441
# Epoch 107/500.. Train Loss: 1901.6101.. Val Loss: 1895.7974
# Epoch 108/500.. Train Loss: 1902.1519.. Val Loss: 1888.2436
# Epoch 109/500.. Train Loss: 1899.8287.. Val Loss: 1902.2509
# Epoch 110/500.. Train Loss: 1901.8805.. Val Loss: 1915.0866
# Epoch 111/500.. Train Loss: 1909.0288.. Val Loss: 1890.9016
# Epoch 112/500.. Train Loss: 1910.5407.. Val Loss: 1893.3752
# Epoch 113/500.. Train Loss: 1900.6786.. Val Loss: 1888.9902
# Epoch 114/500.. Train Loss: 1896.7166.. Val Loss: 1901.9858
# Epoch 115/500.. Train Loss: 1896.6250.. Val Loss: 1895.5735
# Epoch 116/500.. Train Loss: 1898.1119.. Val Loss: 1915.3615
# Epoch 117/500.. Train Loss: 1893.1035.. Val Loss: 1885.0460
# Epoch 118/500.. Train Loss: 1891.1651.. Val Loss: 1885.4137
# Epoch 119/500.. Train Loss: 1889.2405.. Val Loss: 1877.3572
# Epoch 120/500.. Train Loss: 1888.2233.. Val Loss: 1887.6367
# Epoch 121/500.. Train Loss: 1883.1014.. Val Loss: 1869.8725
# Epoch 122/500.. Train Loss: 1875.2307.. Val Loss: 1877.4435
# Epoch 123/500.. Train Loss: 1875.2313.. Val Loss: 1870.8720
# Epoch 124/500.. Train Loss: 1879.5570.. Val Loss: 1857.1060
# Epoch 125/500.. Train Loss: 1870.5871.. Val Loss: 1857.6307
# Epoch 126/500.. Train Loss: 1858.6072.. Val Loss: 1875.0158
# Epoch 127/500.. Train Loss: 1859.9536.. Val Loss: 1883.5700
# Epoch 128/500.. Train Loss: 1859.7837.. Val Loss: 1851.5117
# Epoch 129/500.. Train Loss: 1851.3756.. Val Loss: 1852.3574
# Epoch 130/500.. Train Loss: 1843.3517.. Val Loss: 1840.6381
# Epoch 131/500.. Train Loss: 1832.9217.. Val Loss: 1851.1710
# Epoch 132/500.. Train Loss: 1832.2306.. Val Loss: 1820.2163
# Epoch 133/500.. Train Loss: 1824.0558.. Val Loss: 1834.2534
# Epoch 134/500.. Train Loss: 1822.7909.. Val Loss: 1847.8196
# Epoch 135/500.. Train Loss: 1820.9823.. Val Loss: 1867.8842
# Epoch 136/500.. Train Loss: 1808.6814.. Val Loss: 1814.1935
# Epoch 137/500.. Train Loss: 1800.8904.. Val Loss: 1921.8849
# Epoch 138/500.. Train Loss: 1803.4910.. Val Loss: 1793.0639
# Epoch 139/500.. Train Loss: 1794.1317.. Val Loss: 1765.7631
# Epoch 140/500.. Train Loss: 1787.8910.. Val Loss: 1762.1220
# Epoch 141/500.. Train Loss: 1777.0074.. Val Loss: 1773.4309
# Epoch 142/500.. Train Loss: 1757.4464.. Val Loss: 1839.8748
# Epoch 143/500.. Train Loss: 1744.7806.. Val Loss: 1747.3036
# Epoch 144/500.. Train Loss: 1735.9483.. Val Loss: 1743.7173
# Epoch 145/500.. Train Loss: 1724.2546.. Val Loss: 1741.6040
# Epoch 146/500.. Train Loss: 1714.0367.. Val Loss: 1780.4155
# Epoch 147/500.. Train Loss: 1699.4624.. Val Loss: 1708.9263
# Epoch 148/500.. Train Loss: 1701.0361.. Val Loss: 1732.3327
# Epoch 149/500.. Train Loss: 1682.5261.. Val Loss: 1731.4707
# Epoch 150/500.. Train Loss: 1691.5258.. Val Loss: 1746.1632
# Epoch 151/500.. Train Loss: 1686.4166.. Val Loss: 1669.1880
# Epoch 152/500.. Train Loss: 1656.2537.. Val Loss: 1819.2377
# Epoch 153/500.. Train Loss: 1674.3092.. Val Loss: 1716.2431
# Epoch 154/500.. Train Loss: 1647.7496.. Val Loss: 1647.8498
# Epoch 155/500.. Train Loss: 1631.8451.. Val Loss: 1783.7358
# Epoch 156/500.. Train Loss: 1612.0079.. Val Loss: 1647.6142
# Epoch 157/500.. Train Loss: 1604.4577.. Val Loss: 1660.1214
# Epoch 158/500.. Train Loss: 1599.9791.. Val Loss: 1682.4792
# Epoch 159/500.. Train Loss: 1588.9909.. Val Loss: 1577.4794
# Epoch 160/500.. Train Loss: 1567.1617.. Val Loss: 1863.6903
# Epoch 161/500.. Train Loss: 1555.1096.. Val Loss: 1621.3667
# Epoch 162/500.. Train Loss: 1547.7483.. Val Loss: 1687.0930
# Epoch 163/500.. Train Loss: 1543.1598.. Val Loss: 1555.2298
# Epoch 164/500.. Train Loss: 1525.2325.. Val Loss: 1566.5774
# Epoch 165/500.. Train Loss: 1523.3261.. Val Loss: 1592.2427
# Epoch 166/500.. Train Loss: 1507.7838.. Val Loss: 1564.9018
# Epoch 167/500.. Train Loss: 1505.7446.. Val Loss: 1632.6035
# Epoch 168/500.. Train Loss: 1478.4779.. Val Loss: 1583.2761
# Epoch 169/500.. Train Loss: 1494.3962.. Val Loss: 1595.3017
# Epoch 170/500.. Train Loss: 1456.9394.. Val Loss: 1496.3322
# Epoch 171/500.. Train Loss: 1466.9212.. Val Loss: 1474.1397
# Epoch 172/500.. Train Loss: 1484.5348.. Val Loss: 2336.8427
# Epoch 173/500.. Train Loss: 1502.4804.. Val Loss: 1583.3169
# Epoch 174/500.. Train Loss: 1451.2766.. Val Loss: 2415.0909
# Epoch 175/500.. Train Loss: 1440.5766.. Val Loss: 2546.9638
# Epoch 176/500.. Train Loss: 1452.3065.. Val Loss: 1470.8864
# Epoch 177/500.. Train Loss: 1447.3396.. Val Loss: 2130.6784
# Epoch 178/500.. Train Loss: 1479.1444.. Val Loss: 1698.8370
# Epoch 179/500.. Train Loss: 1478.9846.. Val Loss: 3347.2362
# Epoch 180/500.. Train Loss: 1436.9052.. Val Loss: 2441.4890
# Epoch 181/500.. Train Loss: 1472.9957.. Val Loss: 1915.0220
# Epoch 182/500.. Train Loss: 1435.2454.. Val Loss: 1923.0320
# Epoch 183/500.. Train Loss: 1381.0221.. Val Loss: 1589.1596
# Epoch 184/500.. Train Loss: 1387.6315.. Val Loss: 1512.8778
# Epoch 185/500.. Train Loss: 1370.9460.. Val Loss: 1736.9176
# Epoch 186/500.. Train Loss: 1309.8014.. Val Loss: 1305.4390
# Epoch 187/500.. Train Loss: 1325.7711.. Val Loss: 1327.4879
# Epoch 188/500.. Train Loss: 1301.8993.. Val Loss: 1433.4382
# Epoch 189/500.. Train Loss: 1292.0738.. Val Loss: 1313.2685
# Epoch 190/500.. Train Loss: 1288.8938.. Val Loss: 1352.5399
# Epoch 191/500.. Train Loss: 1287.4520.. Val Loss: 1280.7995
# Epoch 192/500.. Train Loss: 1254.1188.. Val Loss: 1258.1410
# Epoch 193/500.. Train Loss: 1236.0775.. Val Loss: 1262.3054
# Epoch 194/500.. Train Loss: 1229.7950.. Val Loss: 1240.2610
# Epoch 195/500.. Train Loss: 1214.1756.. Val Loss: 1452.4845
# Epoch 196/500.. Train Loss: 1227.4470.. Val Loss: 1224.0102
# Epoch 197/500.. Train Loss: 1227.1647.. Val Loss: 1267.2915
# Epoch 198/500.. Train Loss: 1208.3764.. Val Loss: 1209.6012
# Epoch 199/500.. Train Loss: 1187.6911.. Val Loss: 1275.8793
# Epoch 200/500.. Train Loss: 1177.5235.. Val Loss: 1419.7876
# Epoch 201/500.. Train Loss: 1268.8753.. Val Loss: 5547.9251
# Epoch 202/500.. Train Loss: 1351.6469.. Val Loss: 1462.7990
# Epoch 203/500.. Train Loss: 1248.3631.. Val Loss: 2370.9828
# Epoch 204/500.. Train Loss: 1223.6691.. Val Loss: 1716.9006
# Epoch 205/500.. Train Loss: 1221.9759.. Val Loss: 2217.6772
# Epoch 206/500.. Train Loss: 1192.7308.. Val Loss: 1181.8969
# Epoch 207/500.. Train Loss: 1183.0913.. Val Loss: 1164.2593
# Epoch 208/500.. Train Loss: 1150.1545.. Val Loss: 2125.2395
# Epoch 209/500.. Train Loss: 1143.9884.. Val Loss: 1145.6650
# Epoch 210/500.. Train Loss: 1140.5905.. Val Loss: 1437.6491
# Epoch 211/500.. Train Loss: 1118.8160.. Val Loss: 1260.7741
# Epoch 212/500.. Train Loss: 1100.6015.. Val Loss: 1154.2161
# Epoch 213/500.. Train Loss: 1104.2942.. Val Loss: 1183.5098
# Epoch 214/500.. Train Loss: 1098.7899.. Val Loss: 1109.5494
# Epoch 215/500.. Train Loss: 1077.5367.. Val Loss: 1106.9806
# Epoch 216/500.. Train Loss: 1075.8147.. Val Loss: 1179.9267
# Epoch 217/500.. Train Loss: 1071.6121.. Val Loss: 1060.5468
# Epoch 218/500.. Train Loss: 1049.8415.. Val Loss: 1134.9506
# Epoch 219/500.. Train Loss: 1046.6121.. Val Loss: 1097.0263
# Epoch 220/500.. Train Loss: 1048.6085.. Val Loss: 1235.3526
# Epoch 221/500.. Train Loss: 1041.5822.. Val Loss: 1064.2117
# Epoch 222/500.. Train Loss: 1034.0812.. Val Loss: 1094.9851
# Epoch 223/500.. Train Loss: 1032.4584.. Val Loss: 1029.9563
# Epoch 224/500.. Train Loss: 1018.5955.. Val Loss: 1068.2960
# Epoch 225/500.. Train Loss: 1019.6659.. Val Loss: 1056.3913
# Epoch 226/500.. Train Loss: 1009.6549.. Val Loss: 1070.6440
# Epoch 227/500.. Train Loss: 1006.7792.. Val Loss: 1007.5343
# Epoch 228/500.. Train Loss: 1010.6732.. Val Loss: 1061.5716
# Epoch 229/500.. Train Loss: 1001.1575.. Val Loss: 1102.5977
# Epoch 230/500.. Train Loss: 1005.0114.. Val Loss: 1081.6670
# Epoch 231/500.. Train Loss: 991.5917.. Val Loss: 1026.0994
# Epoch 232/500.. Train Loss: 991.9658.. Val Loss: 1227.3965
# Epoch 233/500.. Train Loss: 982.8034.. Val Loss: 1003.1511
# Epoch 234/500.. Train Loss: 975.7337.. Val Loss: 1080.5320
# Epoch 235/500.. Train Loss: 991.0301.. Val Loss: 1757.4904
# Epoch 236/500.. Train Loss: 1020.8611.. Val Loss: 1033.6300
# Epoch 237/500.. Train Loss: 1003.4411.. Val Loss: 1329.4078
# Epoch 238/500.. Train Loss: 983.6644.. Val Loss: 1181.1797
# Epoch 239/500.. Train Loss: 982.0655.. Val Loss: 1088.4038
# Epoch 240/500.. Train Loss: 962.4295.. Val Loss: 1133.8937
# Epoch 241/500.. Train Loss: 961.8522.. Val Loss: 976.5976
# Epoch 242/500.. Train Loss: 953.2296.. Val Loss: 961.9132
# Epoch 243/500.. Train Loss: 959.3327.. Val Loss: 950.8415
# Epoch 244/500.. Train Loss: 956.7509.. Val Loss: 938.5967
# Epoch 245/500.. Train Loss: 946.8329.. Val Loss: 1017.9988
# Epoch 246/500.. Train Loss: 942.4766.. Val Loss: 933.3453
# Epoch 247/500.. Train Loss: 934.9447.. Val Loss: 938.5656
# Epoch 248/500.. Train Loss: 936.5358.. Val Loss: 1077.7210
# Epoch 249/500.. Train Loss: 925.4931.. Val Loss: 993.1282
# Epoch 250/500.. Train Loss: 925.8580.. Val Loss: 928.3970
# Epoch 251/500.. Train Loss: 928.9906.. Val Loss: 978.9221
# Epoch 252/500.. Train Loss: 922.1372.. Val Loss: 970.4057
# Epoch 253/500.. Train Loss: 922.5418.. Val Loss: 937.3901
# Epoch 254/500.. Train Loss: 927.9045.. Val Loss: 912.8680
# Epoch 255/500.. Train Loss: 913.5849.. Val Loss: 926.1765
# Epoch 256/500.. Train Loss: 915.9353.. Val Loss: 920.3192
# Epoch 257/500.. Train Loss: 929.3724.. Val Loss: 966.7510
# Epoch 258/500.. Train Loss: 923.9078.. Val Loss: 1026.2133
# Epoch 259/500.. Train Loss: 917.0046.. Val Loss: 919.8310
# Epoch 260/500.. Train Loss: 911.4377.. Val Loss: 920.2098
# Epoch 261/500.. Train Loss: 909.4866.. Val Loss: 943.2428
# Epoch 262/500.. Train Loss: 901.9412.. Val Loss: 945.7033
# Epoch 263/500.. Train Loss: 901.4928.. Val Loss: 909.4109
# Epoch 264/500.. Train Loss: 894.2246.. Val Loss: 898.5850
# Epoch 265/500.. Train Loss: 896.6453.. Val Loss: 891.7137
# Epoch 266/500.. Train Loss: 894.8053.. Val Loss: 893.0529
# Epoch 267/500.. Train Loss: 893.7980.. Val Loss: 906.6637
# Epoch 268/500.. Train Loss: 891.9694.. Val Loss: 888.2168
# Epoch 269/500.. Train Loss: 887.1707.. Val Loss: 884.0768
# Epoch 270/500.. Train Loss: 891.1761.. Val Loss: 880.3905
# Epoch 271/500.. Train Loss: 884.3730.. Val Loss: 911.0595
# Epoch 272/500.. Train Loss: 889.5889.. Val Loss: 882.8757
# Epoch 273/500.. Train Loss: 885.1881.. Val Loss: 875.7007
# Epoch 274/500.. Train Loss: 881.3978.. Val Loss: 884.6261
# Epoch 275/500.. Train Loss: 883.3129.. Val Loss: 881.6333
# Epoch 276/500.. Train Loss: 880.5840.. Val Loss: 885.5269
# Epoch 277/500.. Train Loss: 880.5270.. Val Loss: 877.3411
# Epoch 278/500.. Train Loss: 883.3178.. Val Loss: 875.7289
# Epoch 279/500.. Train Loss: 877.2981.. Val Loss: 884.3194
# Epoch 280/500.. Train Loss: 885.2056.. Val Loss: 882.0334
# Epoch 281/500.. Train Loss: 877.4862.. Val Loss: 880.7747
# Epoch 282/500.. Train Loss: 879.2883.. Val Loss: 876.1809
# Epoch 283/500.. Train Loss: 873.1542.. Val Loss: 870.8946
# Epoch 284/500.. Train Loss: 874.5077.. Val Loss: 876.8902
# Epoch 285/500.. Train Loss: 887.8689.. Val Loss: 876.9301
# Epoch 286/500.. Train Loss: 871.9947.. Val Loss: 875.2311
# Epoch 287/500.. Train Loss: 878.7883.. Val Loss: 879.3055
# Epoch 288/500.. Train Loss: 870.6555.. Val Loss: 870.8233
# Epoch 289/500.. Train Loss: 875.9976.. Val Loss: 866.0702
# Epoch 290/500.. Train Loss: 875.4600.. Val Loss: 870.6268
# Epoch 291/500.. Train Loss: 882.8052.. Val Loss: 875.9909
# Epoch 292/500.. Train Loss: 874.7638.. Val Loss: 870.0819
# Epoch 293/500.. Train Loss: 878.5590.. Val Loss: 870.0274
# Epoch 294/500.. Train Loss: 871.7350.. Val Loss: 865.2575
# Epoch 295/500.. Train Loss: 870.2851.. Val Loss: 865.2994
# Epoch 296/500.. Train Loss: 873.5726.. Val Loss: 869.2798
# Epoch 297/500.. Train Loss: 875.6685.. Val Loss: 866.8155
# Epoch 298/500.. Train Loss: 873.7075.. Val Loss: 870.9070
# Epoch 299/500.. Train Loss: 870.7424.. Val Loss: 875.1925
# Epoch 300/500.. Train Loss: 875.7510.. Val Loss: 877.5100
# Epoch 301/500.. Train Loss: 880.6422.. Val Loss: 871.7374
# Epoch 302/500.. Train Loss: 871.9064.. Val Loss: 866.5144
# Epoch 303/500.. Train Loss: 874.5810.. Val Loss: 870.3326
# Epoch 304/500.. Train Loss: 874.1260.. Val Loss: 870.4885
# Epoch 305/500.. Train Loss: 879.9430.. Val Loss: 867.7509
# Epoch 306/500.. Train Loss: 871.2942.. Val Loss: 870.9975
# Epoch 307/500.. Train Loss: 873.1114.. Val Loss: 873.2377
# Epoch 308/500.. Train Loss: 873.3836.. Val Loss: 872.6653
# Epoch 309/500.. Train Loss: 872.9377.. Val Loss: 867.9393
# Epoch 310/500.. Train Loss: 875.6363.. Val Loss: 869.6673
# Epoch 311/500.. Train Loss: 869.1679.. Val Loss: 871.7592
# Epoch 312/500.. Train Loss: 871.2479.. Val Loss: 867.5943
# Epoch 313/500.. Train Loss: 871.4341.. Val Loss: 874.3137
# Epoch 314/500.. Train Loss: 872.0195.. Val Loss: 872.0503
# Epoch 315/500.. Train Loss: 874.9131.. Val Loss: 865.5517
# Epoch 316/500.. Train Loss: 872.1455.. Val Loss: 869.4926
# Epoch 317/500.. Train Loss: 871.5109.. Val Loss: 870.4232
# Epoch 318/500.. Train Loss: 873.6856.. Val Loss: 870.4361
# Epoch 319/500.. Train Loss: 872.6989.. Val Loss: 886.8852
# Epoch 320/500.. Train Loss: 873.5469.. Val Loss: 872.2090
# Epoch 321/500.. Train Loss: 874.1909.. Val Loss: 869.7131
# Epoch 322/500.. Train Loss: 867.0433.. Val Loss: 871.5447
# Epoch 323/500.. Train Loss: 872.8385.. Val Loss: 879.0833
# Epoch 324/500.. Train Loss: 873.2866.. Val Loss: 868.6204
# Epoch 325/500.. Train Loss: 869.7406.. Val Loss: 894.8788
# Epoch 326/500.. Train Loss: 868.6392.. Val Loss: 870.9321
# Epoch 327/500.. Train Loss: 868.0049.. Val Loss: 867.5828
# Epoch 328/500.. Train Loss: 867.2245.. Val Loss: 865.0762
# Epoch 329/500.. Train Loss: 868.8190.. Val Loss: 867.4930
# Epoch 330/500.. Train Loss: 864.6040.. Val Loss: 866.0658
# Epoch 331/500.. Train Loss: 866.9806.. Val Loss: 865.9084
# Epoch 332/500.. Train Loss: 867.9871.. Val Loss: 882.3039
# Epoch 333/500.. Train Loss: 874.6787.. Val Loss: 890.9571
# Epoch 334/500.. Train Loss: 870.7590.. Val Loss: 878.3854
# Epoch 335/500.. Train Loss: 864.0293.. Val Loss: 880.9663
# Epoch 336/500.. Train Loss: 866.2888.. Val Loss: 862.7391
# Epoch 337/500.. Train Loss: 869.2029.. Val Loss: 867.6001
# Epoch 338/500.. Train Loss: 862.0378.. Val Loss: 883.1321
# Epoch 339/500.. Train Loss: 868.6260.. Val Loss: 895.9379
# Epoch 340/500.. Train Loss: 864.9106.. Val Loss: 894.6483
# Epoch 341/500.. Train Loss: 859.1252.. Val Loss: 865.4751
# Epoch 342/500.. Train Loss: 861.4933.. Val Loss: 884.0441
# Epoch 343/500.. Train Loss: 860.5755.. Val Loss: 866.0546
# Epoch 344/500.. Train Loss: 861.2126.. Val Loss: 915.0527
# Epoch 345/500.. Train Loss: 859.2322.. Val Loss: 887.4769
# Epoch 346/500.. Train Loss: 853.5813.. Val Loss: 847.2828
# Epoch 347/500.. Train Loss: 857.6509.. Val Loss: 863.3816
# Epoch 348/500.. Train Loss: 854.3834.. Val Loss: 849.7851
# Epoch 349/500.. Train Loss: 865.9931.. Val Loss: 862.0585
# Epoch 350/500.. Train Loss: 851.4703.. Val Loss: 876.9366
# Epoch 351/500.. Train Loss: 859.4643.. Val Loss: 935.6785
# Epoch 352/500.. Train Loss: 849.6927.. Val Loss: 964.0797
# Epoch 353/500.. Train Loss: 846.0155.. Val Loss: 876.6309
# Epoch 354/500.. Train Loss: 859.0625.. Val Loss: 864.2128
# Epoch 355/500.. Train Loss: 851.5028.. Val Loss: 905.4916
# Epoch 356/500.. Train Loss: 848.3306.. Val Loss: 871.2834
# Epoch 357/500.. Train Loss: 837.4416.. Val Loss: 925.5241
# Epoch 358/500.. Train Loss: 845.3431.. Val Loss: 840.0805
# Epoch 359/500.. Train Loss: 836.5517.. Val Loss: 844.9289
# Epoch 360/500.. Train Loss: 833.9346.. Val Loss: 827.7963
# Epoch 361/500.. Train Loss: 836.2309.. Val Loss: 871.7072
# Epoch 362/500.. Train Loss: 848.4426.. Val Loss: 841.9773
# Epoch 363/500.. Train Loss: 861.5152.. Val Loss: 889.7869
# Epoch 364/500.. Train Loss: 836.6730.. Val Loss: 824.9481
# Epoch 365/500.. Train Loss: 833.1703.. Val Loss: 846.5138
# Epoch 366/500.. Train Loss: 861.3372.. Val Loss: 866.3303
# Epoch 367/500.. Train Loss: 847.9565.. Val Loss: 942.4432
# Epoch 368/500.. Train Loss: 835.4932.. Val Loss: 882.8190
# Epoch 369/500.. Train Loss: 829.7057.. Val Loss: 915.4196
# Epoch 370/500.. Train Loss: 823.5470.. Val Loss: 942.1680
# Epoch 371/500.. Train Loss: 812.1647.. Val Loss: 892.4715
# Epoch 372/500.. Train Loss: 813.4970.. Val Loss: 854.7503
# Epoch 373/500.. Train Loss: 810.9563.. Val Loss: 815.8363
# Epoch 374/500.. Train Loss: 800.6190.. Val Loss: 948.2544
# Epoch 375/500.. Train Loss: 861.4700.. Val Loss: 3736.5813
# Epoch 376/500.. Train Loss: 929.3157.. Val Loss: 1373.1527
# Epoch 377/500.. Train Loss: 880.8167.. Val Loss: 4663.2486
# Epoch 378/500.. Train Loss: 1067.8317.. Val Loss: 3188.9141
# Epoch 379/500.. Train Loss: 1008.6495.. Val Loss: 4995.1712
# Epoch 380/500.. Train Loss: 1109.4944.. Val Loss: 13834.8722
# Epoch 381/500.. Train Loss: 2525.2421.. Val Loss: 11320.8977
# Epoch 382/500.. Train Loss: 2968.9417.. Val Loss: 3877.7170
# Epoch 383/500.. Train Loss: 1739.0042.. Val Loss: 10054.0213
# Epoch 384/500.. Train Loss: 2399.9142.. Val Loss: 4979.2440
# Epoch 385/500.. Train Loss: 5011.0179.. Val Loss: 26180.2216
# Epoch 386/500.. Train Loss: 12388.8643.. Val Loss: 24871.8239
# Epoch 387/500.. Train Loss: 14024.8321.. Val Loss: 17059.8153
# Epoch 388/500.. Train Loss: 10939.2520.. Val Loss: 10520.5533
# Epoch 389/500.. Train Loss: 7408.9055.. Val Loss: 6039.7571
# Epoch 390/500.. Train Loss: 4941.6535.. Val Loss: 4998.1580
# Epoch 391/500.. Train Loss: 3437.2712.. Val Loss: 9135.7053
# Epoch 392/500.. Train Loss: 2529.5803.. Val Loss: 18721.2287
# Epoch 393/500.. Train Loss: 4738.5710.. Val Loss: 11140.5902
# Epoch 394/500.. Train Loss: 4553.2627.. Val Loss: 11807.2869
# Epoch 395/500.. Train Loss: 6980.2087.. Val Loss: 13851.6903
# Epoch 396/500.. Train Loss: 6786.7359.. Val Loss: 6502.4162
# Epoch 397/500.. Train Loss: 5039.7804.. Val Loss: 4812.0039
# Epoch 398/500.. Train Loss: 4092.7740.. Val Loss: 7126.7862
# Epoch 399/500.. Train Loss: 3428.6078.. Val Loss: 8701.3963
# Epoch 400/500.. Train Loss: 2646.2568.. Val Loss: 7111.2763
# Epoch 401/500.. Train Loss: 1987.9043.. Val Loss: 7561.2429
# Epoch 402/500.. Train Loss: 1552.6324.. Val Loss: 11720.7486
# Epoch 403/500.. Train Loss: 1298.5846.. Val Loss: 18808.2997
# Epoch 404/500.. Train Loss: 1203.0222.. Val Loss: 16828.5639
# Epoch 405/500.. Train Loss: 1132.1768.. Val Loss: 11214.1626
# Epoch 406/500.. Train Loss: 1100.6045.. Val Loss: 8987.0760
# Epoch 407/500.. Train Loss: 1038.1066.. Val Loss: 10361.2024
# Epoch 408/500.. Train Loss: 986.6870.. Val Loss: 6878.0135
# Epoch 409/500.. Train Loss: 963.0202.. Val Loss: 5180.6673
# Epoch 410/500.. Train Loss: 931.0005.. Val Loss: 5546.4723
# Epoch 411/500.. Train Loss: 909.7553.. Val Loss: 3067.5153
# Epoch 412/500.. Train Loss: 901.8488.. Val Loss: 1509.8775
# Epoch 413/500.. Train Loss: 877.0777.. Val Loss: 2567.5502
# Epoch 414/500.. Train Loss: 867.6101.. Val Loss: 1146.0538
# Epoch 415/500.. Train Loss: 855.7713.. Val Loss: 1036.4474
# Epoch 416/500.. Train Loss: 847.4992.. Val Loss: 1224.4952
# Epoch 417/500.. Train Loss: 836.3438.. Val Loss: 1076.0943
# Epoch 418/500.. Train Loss: 843.6754.. Val Loss: 933.3881
# Epoch 419/500.. Train Loss: 825.0985.. Val Loss: 908.3739
# Epoch 420/500.. Train Loss: 813.4494.. Val Loss: 809.3746
# Epoch 421/500.. Train Loss: 811.9031.. Val Loss: 854.4769
# Epoch 422/500.. Train Loss: 803.1674.. Val Loss: 813.1419
# Epoch 423/500.. Train Loss: 794.8733.. Val Loss: 798.4555
# Epoch 424/500.. Train Loss: 795.0170.. Val Loss: 822.7803
# Epoch 425/500.. Train Loss: 782.6968.. Val Loss: 777.7566
# Epoch 426/500.. Train Loss: 773.6778.. Val Loss: 820.3048
# Epoch 427/500.. Train Loss: 780.6576.. Val Loss: 778.4785
# Epoch 428/500.. Train Loss: 784.0093.. Val Loss: 818.6141
# Epoch 429/500.. Train Loss: 779.2558.. Val Loss: 776.4551
# Epoch 430/500.. Train Loss: 774.3923.. Val Loss: 786.5128
# Epoch 431/500.. Train Loss: 762.4050.. Val Loss: 787.1173
# Epoch 432/500.. Train Loss: 763.6873.. Val Loss: 768.9566
# Epoch 433/500.. Train Loss: 761.9916.. Val Loss: 758.2851
# Epoch 434/500.. Train Loss: 764.3174.. Val Loss: 803.0795
# Epoch 435/500.. Train Loss: 753.6175.. Val Loss: 806.5207
# Epoch 436/500.. Train Loss: 755.2461.. Val Loss: 785.9240
# Epoch 437/500.. Train Loss: 752.7468.. Val Loss: 755.5087
# Epoch 438/500.. Train Loss: 752.0215.. Val Loss: 759.6987
# Epoch 439/500.. Train Loss: 756.2108.. Val Loss: 754.6729
# Epoch 440/500.. Train Loss: 748.4318.. Val Loss: 783.4031
# Epoch 441/500.. Train Loss: 750.7711.. Val Loss: 771.0945
# Epoch 442/500.. Train Loss: 736.5705.. Val Loss: 763.4310
# Epoch 443/500.. Train Loss: 735.8564.. Val Loss: 748.8099
# Epoch 444/500.. Train Loss: 734.4556.. Val Loss: 738.4569
# Epoch 445/500.. Train Loss: 731.0676.. Val Loss: 736.8903
# Epoch 446/500.. Train Loss: 733.0023.. Val Loss: 737.5737
# Epoch 447/500.. Train Loss: 728.4991.. Val Loss: 744.9467
# Epoch 448/500.. Train Loss: 734.4749.. Val Loss: 724.4461
# Epoch 449/500.. Train Loss: 725.8747.. Val Loss: 720.1820
# Epoch 450/500.. Train Loss: 725.9605.. Val Loss: 755.0349
# Epoch 451/500.. Train Loss: 727.1369.. Val Loss: 721.8246
# Epoch 452/500.. Train Loss: 718.8052.. Val Loss: 728.8807
# Epoch 453/500.. Train Loss: 728.6463.. Val Loss: 731.3088
# Epoch 454/500.. Train Loss: 718.4848.. Val Loss: 719.8965
# Epoch 455/500.. Train Loss: 721.7496.. Val Loss: 716.0739
# Epoch 456/500.. Train Loss: 721.9979.. Val Loss: 731.6206
# Epoch 457/500.. Train Loss: 714.8222.. Val Loss: 726.1345
# Epoch 458/500.. Train Loss: 726.8033.. Val Loss: 720.2018
# Epoch 459/500.. Train Loss: 717.7779.. Val Loss: 724.9162
# Epoch 460/500.. Train Loss: 709.2178.. Val Loss: 713.1254
# Epoch 461/500.. Train Loss: 716.2240.. Val Loss: 715.3327
# Epoch 462/500.. Train Loss: 706.8810.. Val Loss: 706.6520
# Epoch 463/500.. Train Loss: 715.2397.. Val Loss: 709.1630
# Epoch 464/500.. Train Loss: 714.9944.. Val Loss: 703.3439
# Epoch 465/500.. Train Loss: 700.8529.. Val Loss: 713.9802
# Epoch 466/500.. Train Loss: 707.7245.. Val Loss: 711.8635
# Epoch 467/500.. Train Loss: 707.9839.. Val Loss: 706.6239
# Epoch 468/500.. Train Loss: 699.6848.. Val Loss: 707.5367
# Epoch 469/500.. Train Loss: 704.3298.. Val Loss: 702.3939
# Epoch 470/500.. Train Loss: 702.9826.. Val Loss: 709.9153
# Epoch 471/500.. Train Loss: 700.5363.. Val Loss: 709.7132
# Epoch 472/500.. Train Loss: 704.5287.. Val Loss: 707.9165
# Epoch 473/500.. Train Loss: 701.5402.. Val Loss: 709.4863
# Epoch 474/500.. Train Loss: 698.5071.. Val Loss: 719.9105
# Epoch 475/500.. Train Loss: 699.1367.. Val Loss: 708.0242
# Epoch 476/500.. Train Loss: 700.6872.. Val Loss: 713.1713
# Epoch 477/500.. Train Loss: 698.0938.. Val Loss: 707.7385
# Epoch 478/500.. Train Loss: 699.1663.. Val Loss: 698.2783
# Epoch 479/500.. Train Loss: 696.9334.. Val Loss: 701.5514
# Epoch 480/500.. Train Loss: 697.8110.. Val Loss: 699.0985
# Epoch 481/500.. Train Loss: 694.1911.. Val Loss: 704.4030
# Epoch 482/500.. Train Loss: 702.7849.. Val Loss: 692.2994
# Epoch 483/500.. Train Loss: 691.2679.. Val Loss: 699.3887
# Epoch 484/500.. Train Loss: 699.8421.. Val Loss: 699.0131
# Epoch 485/500.. Train Loss: 697.8302.. Val Loss: 707.1353
# Epoch 486/500.. Train Loss: 693.5898.. Val Loss: 703.3086
# Epoch 487/500.. Train Loss: 692.6288.. Val Loss: 697.2736
# Epoch 488/500.. Train Loss: 698.2181.. Val Loss: 695.9146
# Epoch 489/500.. Train Loss: 704.3768.. Val Loss: 698.4982
# Epoch 490/500.. Train Loss: 698.9692.. Val Loss: 705.0533
# Epoch 491/500.. Train Loss: 697.3918.. Val Loss: 694.9656
# Epoch 492/500.. Train Loss: 695.6021.. Val Loss: 698.3682
# Epoch 493/500.. Train Loss: 692.6660.. Val Loss: 698.0676
# Epoch 494/500.. Train Loss: 695.9810.. Val Loss: 699.6616
# Epoch 495/500.. Train Loss: 693.4597.. Val Loss: 695.0953
# Epoch 496/500.. Train Loss: 700.3158.. Val Loss: 697.8818
# Epoch 497/500.. Train Loss: 690.2331.. Val Loss: 705.9581
# Epoch 498/500.. Train Loss: 696.7334.. Val Loss: 698.6151
# Epoch 499/500.. Train Loss: 697.0707.. Val Loss: 705.3898
# Epoch 500/500.. Train Loss: 692.1306.. Val Loss: 693.5111

# %%
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Calculate the reconstruction loss
# The reconstruction loss between good products and defective products should have difference.
#
# You can use the following codes to evaluate the reconstruction loss, and find something useful information.

# %%
import os
import torch
from PIL import Image
import matplotlib.pyplot as plt

images = []

model = VAE(LATENT_DIM).to(device)
model.load_state_dict(torch.load(PTH_PATH))

def test(image_path, vae, device):
    img = Image.open(image_path)
    img = transform(img).to(device)
    img = img.unsqueeze(0)

    vae.eval()
    with torch.no_grad():
        recon, mu, log_var = vae(img)
        images.append((img, recon))
        test_loss = loss_function(recon, img, mu, log_var)
        return test_loss.item()

testimg_dir = f'./data/test/{DATASET}/good'
testimg_dir2 = f'./data/test/{DATASET}/error'

good = []
error = []
for img_file in os.listdir(testimg_dir):
    img_path = os.path.join(testimg_dir, img_file)
    if os.path.isfile(img_path):
        good.append(test(img_path, model, device))

for img_file in os.listdir(testimg_dir2):
    img_path = os.path.join(testimg_dir2, img_file)
    if os.path.isfile(img_path):
        error.append(test(img_path, model, device))

plt.plot(error, label='defective Loss')
plt.scatter(range(len(error)), error, s=10)
plt.plot(good, label='good Loss')
plt.scatter(range(len(good)), good, s=10)
plt.xlabel('num')
plt.ylabel('Loss')
plt.legend()

print("good avg: ", sum(good)/len(good))    
print("defective avg: ", sum(error)/len(error))
# Out:
# /tmp/ipykernel_1653626/1488696479.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(PTH_PATH))
# good avg:  715.0590263034986
# defective avg:  983.1857081422019

# %% [markdown]
# ## Calculate Accuracy
# You need to calculate the accuracy of products' predictions.
#
# A easy way is to use the reconstruction loss to distinguish between goods and defective ones.
#
# It is not restricted to use this way, you also can use another methods and write they into report.

# %%
from sklearn.metrics import f1_score

def calculate_accuracy_and_f1(threshold=100.0):
    set_seed(42)
    correct = 0
    total = 0
    true_labels = []
    predicted_labels = []

    # Good products (正類)
    for img_file in os.listdir(testimg_dir):
        img_path = os.path.join(testimg_dir, img_file)
        if os.path.isfile(img_path):
            loss = test(img_path, model, device)
            true_labels.append(1)  # 正類標籤
            if loss < threshold:
                predicted_labels.append(1)  # 預測正類
                correct += 1
            else:
                predicted_labels.append(0)  # 預測負類
            total += 1

    # Defective products (負類)
    for img_file in os.listdir(testimg_dir2):
        img_path = os.path.join(testimg_dir2, img_file)
        if os.path.isfile(img_path):
            loss = test(img_path, model, device)
            true_labels.append(0)  # 負類標籤
            if loss >= threshold:
                predicted_labels.append(0)  # 預測負類
                correct += 1
            else:
                predicted_labels.append(1)  # 預測正類
            total += 1

    accuracy = correct / total * 100

    # 計算 F1-score
    f1 = f1_score(true_labels, predicted_labels)

    return accuracy, f1


def find_best_threshold(low=0, high=2000, tolerance=1):
    """
    使用三分搜尋找到最佳的 threshold。
    """
    set_seed(42)
    best_threshold = 0
    best_accuracy = 0

    while high - low > tolerance:
        # 計算兩個中點
        mid1 = low + (high - low) // 3
        mid2 = high - (high - low) // 3

        # 計算兩個中點的準確率
        accuracy1, f11 = calculate_accuracy_and_f1(mid1)
        accuracy2, f12 = calculate_accuracy_and_f1(mid2)

        print(accuracy1, f11, mid1, accuracy2, f12, mid2)

        # 比較兩個中點的準確率
        if accuracy1 > accuracy2:
            if accuracy1 > best_accuracy:
                best_accuracy = accuracy1
                best_threshold = mid1
            high = mid2 - 1
        elif accuracy1 == accuracy2:
            if accuracy1 > best_accuracy:
                best_accuracy = accuracy1
                best_threshold = mid1
            if f11 > f12:
                high = mid2 - 1
            else:
                low = mid1 + 1
        else:
            if accuracy2 > best_accuracy:
                best_accuracy = accuracy2
                best_threshold = mid2
            low = mid1 + 1

    return best_threshold, best_accuracy

# %%
find_best_threshold(500, 1500)
# Out:
# 41.66666666666667 0.3185840707964602 833 31.818181818181817 0.3382352941176471 1167
# 59.84848484848485 0.3614457831325301 722 34.84848484848485 0.3384615384615385 944
# 68.93939393939394 0.32786885245901637 647 49.24242424242424 0.32323232323232326 796
# 78.78787878787878 0.2222222222222222 598 65.15151515151516 0.3611111111111111 697
# 82.57575757575758 0.14814814814814814 565 73.48484848484848 0.36363636363636365 631
# 81.81818181818183 0.0 543 81.81818181818183 0.25 587
# 81.81818181818183 0.2 572 79.54545454545455 0.3076923076923077 602
# 83.33333333333334 0.15384615384615385 563 82.57575757575758 0.25806451612903225 582
# 83.33333333333334 0.15384615384615385 556 81.81818181818183 0.14285714285714285 569
# 82.57575757575758 0.08 552 83.33333333333334 0.15384615384615385 560
# 83.33333333333334 0.15384615384615385 558 83.33333333333334 0.15384615384615385 563
# 83.33333333333334 0.15384615384615385 562 82.57575757575758 0.14814814814814814 565
# 83.33333333333334 0.15384615384615385 560 83.33333333333334 0.15384615384615385 563
# 83.33333333333334 0.15384615384615385 562 83.33333333333334 0.15384615384615385 563
# (563, 83.33333333333334)
